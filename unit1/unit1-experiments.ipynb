# %%
import gym

from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.vec_env import DummyVecEnv

from huggingface_sb3 import package_to_hub

# %%
import wandb
from wandb.integration.sb3 import WandbCallback

run = wandb.init(
    project="hf-deep-rl-class",
    entity="deutschmann",
    sync_tensorboard=True,
    monitor_gym=True
)
# Out:
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/Users/patrick/Projects/deep-rl-class/unit1/wandb/run-20220506_092421-1cdx39il</code>
# Syncing run <strong><a href="https://wandb.ai/deutschmann/hf-deep-rl-class/runs/1cdx39il" target="_blank">robust-music-12</a></strong> to <a href="https://wandb.ai/deutschmann/hf-deep-rl-class" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>

# %%
def get_env(env_name):
    env = gym.make(env_name)
    env = Monitor(env)
    env.reset()
    return env

env_name = "LunarLander-v2"
env = get_env(env_name)

# %%
train_steps = 1_000_000 # int(2e5)

model = PPO(
    "MlpPolicy", 
    env, 
    verbose=1, 
    tensorboard_log=f"runs/{run.id}"
)

model.learn(total_timesteps=train_steps, callback=WandbCallback(
    gradient_save_freq=100,
    verbose=2,
))
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# Logging to runs/2cn87197/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 87.2     |
# |    ep_rew_mean     | -166     |
# | time/              |          |
# |    fps             | 3460     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 87.4         |
# |    ep_rew_mean          | -169         |
# | time/                   |              |
# |    fps                  | 2626         |
# |    iterations           | 2            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0049147257 |
# |    clip_fraction        | 0.0109       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.00215      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 468          |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00387     |
# |    value_loss           | 1.46e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 88.3         |
# |    ep_rew_mean          | -154         |
# | time/                   |              |
# |    fps                  | 2477         |
# |    iterations           | 3            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0053647636 |
# |    clip_fraction        | 0.0223       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.0166       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 383          |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00507     |
# |    value_loss           | 976          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 91.3         |
# |    ep_rew_mean          | -151         |
# | time/                   |              |
# |    fps                  | 2374         |
# |    iterations           | 4            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0076595806 |
# |    clip_fraction        | 0.0381       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -0.0609      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 336          |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00842     |
# |    value_loss           | 612          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 93.8        |
# |    ep_rew_mean          | -143        |
# | time/                   |             |
# |    fps                  | 2354        |
# |    iterations           | 5           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.010920529 |
# |    clip_fraction        | 0.091       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | -0.0135     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 119         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00714    |
# |    value_loss           | 594         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 94.9        |
# |    ep_rew_mean          | -133        |
# | time/                   |             |
# |    fps                  | 2317        |
# |    iterations           | 6           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.010340447 |
# |    clip_fraction        | 0.0913      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.000517    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 144         |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00926    |
# |    value_loss           | 328         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -130         |
# | time/                   |              |
# |    fps                  | 2291         |
# |    iterations           | 7            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0056117955 |
# |    clip_fraction        | 0.0163       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | -0.0203      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 178          |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00581     |
# |    value_loss           | 420          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 104         |
# |    ep_rew_mean          | -133        |
# | time/                   |             |
# |    fps                  | 2259        |
# |    iterations           | 8           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.007540366 |
# |    clip_fraction        | 0.0317      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | -0.0427     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 186         |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00628    |
# |    value_loss           | 518         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 117         |
# |    ep_rew_mean          | -131        |
# | time/                   |             |
# |    fps                  | 2122        |
# |    iterations           | 9           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.008423652 |
# |    clip_fraction        | 0.0765      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | -0.00204    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 285         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 636         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 121         |
# |    ep_rew_mean          | -133        |
# | time/                   |             |
# |    fps                  | 2102        |
# |    iterations           | 10          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.009910045 |
# |    clip_fraction        | 0.0583      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.294       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 76.6        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0063     |
# |    value_loss           | 197         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 128          |
# |    ep_rew_mean          | -135         |
# | time/                   |              |
# |    fps                  | 2089         |
# |    iterations           | 11           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0069243074 |
# |    clip_fraction        | 0.0328       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | -0.318       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 263          |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00379     |
# |    value_loss           | 650          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 140          |
# |    ep_rew_mean          | -139         |
# | time/                   |              |
# |    fps                  | 1992         |
# |    iterations           | 12           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0043154433 |
# |    clip_fraction        | 0.00259      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0.0612       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 131          |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00298     |
# |    value_loss           | 340          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 148         |
# |    ep_rew_mean          | -140        |
# | time/                   |             |
# |    fps                  | 1986        |
# |    iterations           | 13          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.008393141 |
# |    clip_fraction        | 0.0494      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.107       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 262         |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00558    |
# |    value_loss           | 426         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 158         |
# |    ep_rew_mean          | -151        |
# | time/                   |             |
# |    fps                  | 1967        |
# |    iterations           | 14          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.010325971 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.162       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 129         |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0123     |
# |    value_loss           | 296         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 170         |
# |    ep_rew_mean          | -142        |
# | time/                   |             |
# |    fps                  | 1894        |
# |    iterations           | 15          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.009996971 |
# |    clip_fraction        | 0.0567      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.185       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 226         |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00618    |
# |    value_loss           | 406         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 178          |
# |    ep_rew_mean          | -141         |
# | time/                   |              |
# |    fps                  | 1893         |
# |    iterations           | 16           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0068831104 |
# |    clip_fraction        | 0.0139       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0.299        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 71.8         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00508     |
# |    value_loss           | 217          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 177         |
# |    ep_rew_mean          | -140        |
# | time/                   |             |
# |    fps                  | 1897        |
# |    iterations           | 17          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.009051467 |
# |    clip_fraction        | 0.0863      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.419       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 80.3        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0105     |
# |    value_loss           | 254         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 187         |
# |    ep_rew_mean          | -139        |
# | time/                   |             |
# |    fps                  | 1830        |
# |    iterations           | 18          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.010274681 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.426       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 164         |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0132     |
# |    value_loss           | 289         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 198         |
# |    ep_rew_mean          | -132        |
# | time/                   |             |
# |    fps                  | 1743        |
# |    iterations           | 19          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.008413946 |
# |    clip_fraction        | 0.0301      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.391       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 48.2        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00687    |
# |    value_loss           | 202         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 217         |
# |    ep_rew_mean          | -128        |
# | time/                   |             |
# |    fps                  | 1623        |
# |    iterations           | 20          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.010764113 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.413       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.7        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00878    |
# |    value_loss           | 130         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 224         |
# |    ep_rew_mean          | -124        |
# | time/                   |             |
# |    fps                  | 1614        |
# |    iterations           | 21          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.009371594 |
# |    clip_fraction        | 0.0568      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.98       |
# |    explained_variance   | 0.473       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.7        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00589    |
# |    value_loss           | 76.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 238          |
# |    ep_rew_mean          | -117         |
# | time/                   |              |
# |    fps                  | 1578         |
# |    iterations           | 22           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0059009586 |
# |    clip_fraction        | 0.0592       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.11        |
# |    explained_variance   | 0.0789       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 122          |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00569     |
# |    value_loss           | 250          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 255         |
# |    ep_rew_mean          | -116        |
# | time/                   |             |
# |    fps                  | 1524        |
# |    iterations           | 23          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.007670219 |
# |    clip_fraction        | 0.0441      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.469       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 65.1        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00325    |
# |    value_loss           | 281         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 268          |
# |    ep_rew_mean          | -115         |
# | time/                   |              |
# |    fps                  | 1487         |
# |    iterations           | 24           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0063734474 |
# |    clip_fraction        | 0.0596       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.145        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 94.9         |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00689     |
# |    value_loss           | 208          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 282          |
# |    ep_rew_mean          | -113         |
# | time/                   |              |
# |    fps                  | 1457         |
# |    iterations           | 25           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0024387273 |
# |    clip_fraction        | 0.0127       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.209        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 131          |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00396     |
# |    value_loss           | 253          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 288         |
# |    ep_rew_mean          | -115        |
# | time/                   |             |
# |    fps                  | 1444        |
# |    iterations           | 26          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.009800494 |
# |    clip_fraction        | 0.0895      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.371       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 71.7        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00996    |
# |    value_loss           | 180         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | -116        |
# | time/                   |             |
# |    fps                  | 1427        |
# |    iterations           | 27          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.007014699 |
# |    clip_fraction        | 0.0563      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.39        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 106         |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00905    |
# |    value_loss           | 251         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 315          |
# |    ep_rew_mean          | -118         |
# | time/                   |              |
# |    fps                  | 1409         |
# |    iterations           | 28           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0054557845 |
# |    clip_fraction        | 0.0243       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.462        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 78.3         |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00389     |
# |    value_loss           | 302          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 328         |
# |    ep_rew_mean          | -119        |
# | time/                   |             |
# |    fps                  | 1396        |
# |    iterations           | 29          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.006840268 |
# |    clip_fraction        | 0.0572      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.64        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 81.4        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00595    |
# |    value_loss           | 145         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 343          |
# |    ep_rew_mean          | -115         |
# | time/                   |              |
# |    fps                  | 1366         |
# |    iterations           | 30           |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0085480185 |
# |    clip_fraction        | 0.0938       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.508        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 48.8         |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00948     |
# |    value_loss           | 121          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 363          |
# |    ep_rew_mean          | -111         |
# | time/                   |              |
# |    fps                  | 1330         |
# |    iterations           | 31           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0042079757 |
# |    clip_fraction        | 0.025        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.508        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 32.3         |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00458     |
# |    value_loss           | 108          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 374         |
# |    ep_rew_mean          | -106        |
# | time/                   |             |
# |    fps                  | 1323        |
# |    iterations           | 32          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.013745159 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.954      |
# |    explained_variance   | 0.703       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.2        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00831    |
# |    value_loss           | 81.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 386         |
# |    ep_rew_mean          | -105        |
# | time/                   |             |
# |    fps                  | 1305        |
# |    iterations           | 33          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.009023406 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.647       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 48          |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00901    |
# |    value_loss           | 114         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 401        |
# |    ep_rew_mean          | -100       |
# | time/                   |            |
# |    fps                  | 1274       |
# |    iterations           | 34         |
# |    time_elapsed         | 54         |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.00974894 |
# |    clip_fraction        | 0.132      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.01      |
# |    explained_variance   | 0.685      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 26.4       |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.0107    |
# |    value_loss           | 67.6       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 409          |
# |    ep_rew_mean          | -101         |
# | time/                   |              |
# |    fps                  | 1242         |
# |    iterations           | 35           |
# |    time_elapsed         | 57           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0078682555 |
# |    clip_fraction        | 0.0857       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.971       |
# |    explained_variance   | 0.195        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 29.8         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00701     |
# |    value_loss           | 158          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 429          |
# |    ep_rew_mean          | -95.9        |
# | time/                   |              |
# |    fps                  | 1229         |
# |    iterations           | 36           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0090117315 |
# |    clip_fraction        | 0.085        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.953       |
# |    explained_variance   | 0.549        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.29         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00781     |
# |    value_loss           | 21.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 447          |
# |    ep_rew_mean          | -90.6        |
# | time/                   |              |
# |    fps                  | 1218         |
# |    iterations           | 37           |
# |    time_elapsed         | 62           |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0064504687 |
# |    clip_fraction        | 0.0407       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1           |
# |    explained_variance   | 0.383        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 89.7         |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00353     |
# |    value_loss           | 107          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 458         |
# |    ep_rew_mean          | -82.7       |
# | time/                   |             |
# |    fps                  | 1191        |
# |    iterations           | 38          |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.010367647 |
# |    clip_fraction        | 0.0636      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.96       |
# |    explained_variance   | 0.419       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33          |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00633    |
# |    value_loss           | 90          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 475         |
# |    ep_rew_mean          | -78.7       |
# | time/                   |             |
# |    fps                  | 1180        |
# |    iterations           | 39          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.009271584 |
# |    clip_fraction        | 0.0714      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.924      |
# |    explained_variance   | 0.415       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 47.3        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00749    |
# |    value_loss           | 122         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 494         |
# |    ep_rew_mean          | -79         |
# | time/                   |             |
# |    fps                  | 1170        |
# |    iterations           | 40          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.011490528 |
# |    clip_fraction        | 0.0828      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.885      |
# |    explained_variance   | -0.154      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.3        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00777    |
# |    value_loss           | 71.7        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 510        |
# |    ep_rew_mean          | -76.7      |
# | time/                   |            |
# |    fps                  | 1154       |
# |    iterations           | 41         |
# |    time_elapsed         | 72         |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.01381677 |
# |    clip_fraction        | 0.183      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.06      |
# |    explained_variance   | 0.364      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 35.4       |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.00858   |
# |    value_loss           | 128        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 525         |
# |    ep_rew_mean          | -78.3       |
# | time/                   |             |
# |    fps                  | 1139        |
# |    iterations           | 42          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.013026205 |
# |    clip_fraction        | 0.238       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.677       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.45        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0164     |
# |    value_loss           | 9.84        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 547          |
# |    ep_rew_mean          | -73.1        |
# | time/                   |              |
# |    fps                  | 1123         |
# |    iterations           | 43           |
# |    time_elapsed         | 78           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0075573837 |
# |    clip_fraction        | 0.0671       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0.567        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 93.9         |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00432     |
# |    value_loss           | 61.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 560          |
# |    ep_rew_mean          | -71.2        |
# | time/                   |              |
# |    fps                  | 1115         |
# |    iterations           | 44           |
# |    time_elapsed         | 80           |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0070313755 |
# |    clip_fraction        | 0.0631       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.921       |
# |    explained_variance   | 0.192        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 30.4         |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00384     |
# |    value_loss           | 87.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 580         |
# |    ep_rew_mean          | -63.8       |
# | time/                   |             |
# |    fps                  | 1094        |
# |    iterations           | 45          |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.005837147 |
# |    clip_fraction        | 0.0437      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.929      |
# |    explained_variance   | 0.3         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 63          |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00547    |
# |    value_loss           | 49.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 595          |
# |    ep_rew_mean          | -61.5        |
# | time/                   |              |
# |    fps                  | 1083         |
# |    iterations           | 46           |
# |    time_elapsed         | 86           |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0031545209 |
# |    clip_fraction        | 0.0297       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.87        |
# |    explained_variance   | 0.167        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 32.8         |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00164     |
# |    value_loss           | 96.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 603          |
# |    ep_rew_mean          | -58.7        |
# | time/                   |              |
# |    fps                  | 1081         |
# |    iterations           | 47           |
# |    time_elapsed         | 88           |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0067829005 |
# |    clip_fraction        | 0.115        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.883       |
# |    explained_variance   | 0.249        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 25.9         |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00447     |
# |    value_loss           | 52.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 627         |
# |    ep_rew_mean          | -54.9       |
# | time/                   |             |
# |    fps                  | 1067        |
# |    iterations           | 48          |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.009235417 |
# |    clip_fraction        | 0.0775      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.893      |
# |    explained_variance   | 0.413       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.7        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00315    |
# |    value_loss           | 77          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 632         |
# |    ep_rew_mean          | -53         |
# | time/                   |             |
# |    fps                  | 1063        |
# |    iterations           | 49          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.032931898 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.83       |
# |    explained_variance   | 0.613       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.44        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00855    |
# |    value_loss           | 50.7        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 650        |
# |    ep_rew_mean          | -51.4      |
# | time/                   |            |
# |    fps                  | 1058       |
# |    iterations           | 50         |
# |    time_elapsed         | 96         |
# |    total_timesteps      | 102400     |
# | train/                  |            |
# |    approx_kl            | 0.00897674 |
# |    clip_fraction        | 0.082      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.959     |
# |    explained_variance   | 0.666      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 15.6       |
# |    n_updates            | 490        |
# |    policy_gradient_loss | -0.00149   |
# |    value_loss           | 47.1       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 651         |
# |    ep_rew_mean          | -54.2       |
# | time/                   |             |
# |    fps                  | 1049        |
# |    iterations           | 51          |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.011402367 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.925      |
# |    explained_variance   | 0.691       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 55.7        |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00547    |
# |    value_loss           | 59.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 655          |
# |    ep_rew_mean          | -52.2        |
# | time/                   |              |
# |    fps                  | 1045         |
# |    iterations           | 52           |
# |    time_elapsed         | 101          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0033318382 |
# |    clip_fraction        | 0.04         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.938       |
# |    explained_variance   | 0.636        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.1         |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00415     |
# |    value_loss           | 78.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 671         |
# |    ep_rew_mean          | -44.2       |
# | time/                   |             |
# |    fps                  | 1038        |
# |    iterations           | 53          |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.011442827 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.924      |
# |    explained_variance   | 0.778       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.7         |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0042     |
# |    value_loss           | 39.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 680         |
# |    ep_rew_mean          | -42.2       |
# | time/                   |             |
# |    fps                  | 1033        |
# |    iterations           | 54          |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.013190312 |
# |    clip_fraction        | 0.0894      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.87       |
# |    explained_variance   | 0.733       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 57.6        |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.00501    |
# |    value_loss           | 58          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 699         |
# |    ep_rew_mean          | -34.1       |
# | time/                   |             |
# |    fps                  | 1025        |
# |    iterations           | 55          |
# |    time_elapsed         | 109         |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# ...
# | time/                   |            |
# |    fps                  | 1351       |
# |    iterations           | 472        |
# |    time_elapsed         | 715        |
# |    total_timesteps      | 966656     |
# | train/                  |            |
# |    approx_kl            | 0.00306422 |
# |    clip_fraction        | 0.044      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.407     |
# |    explained_variance   | 0.647      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 43.8       |
# |    n_updates            | 4710       |
# |    policy_gradient_loss | -0.00486   |
# |    value_loss           | 149        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 280          |
# |    ep_rew_mean          | 237          |
# | time/                   |              |
# |    fps                  | 1352         |
# |    iterations           | 473          |
# |    time_elapsed         | 716          |
# |    total_timesteps      | 968704       |
# | train/                  |              |
# |    approx_kl            | 0.0065954933 |
# |    clip_fraction        | 0.0796       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.502       |
# |    explained_variance   | 0.936        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.17         |
# |    n_updates            | 4720         |
# |    policy_gradient_loss | 0.00168      |
# |    value_loss           | 17.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 274          |
# |    ep_rew_mean          | 242          |
# | time/                   |              |
# |    fps                  | 1352         |
# |    iterations           | 474          |
# |    time_elapsed         | 717          |
# |    total_timesteps      | 970752       |
# | train/                  |              |
# |    approx_kl            | 0.0045477883 |
# |    clip_fraction        | 0.0663       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.436       |
# |    explained_variance   | 0.644        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18.3         |
# |    n_updates            | 4730         |
# |    policy_gradient_loss | 5.85e-05     |
# |    value_loss           | 69           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 283          |
# |    ep_rew_mean          | 242          |
# | time/                   |              |
# |    fps                  | 1353         |
# |    iterations           | 475          |
# |    time_elapsed         | 718          |
# |    total_timesteps      | 972800       |
# | train/                  |              |
# |    approx_kl            | 0.0068946714 |
# |    clip_fraction        | 0.0761       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.46        |
# |    explained_variance   | 0.971        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.23         |
# |    n_updates            | 4740         |
# |    policy_gradient_loss | 0.000157     |
# |    value_loss           | 15.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 282          |
# |    ep_rew_mean          | 242          |
# | time/                   |              |
# |    fps                  | 1353         |
# |    iterations           | 476          |
# |    time_elapsed         | 720          |
# |    total_timesteps      | 974848       |
# | train/                  |              |
# |    approx_kl            | 0.0031053321 |
# |    clip_fraction        | 0.0253       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.403       |
# |    explained_variance   | 0.816        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.5         |
# |    n_updates            | 4750         |
# |    policy_gradient_loss | -0.000535    |
# |    value_loss           | 54.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 281          |
# |    ep_rew_mean          | 243          |
# | time/                   |              |
# |    fps                  | 1352         |
# |    iterations           | 477          |
# |    time_elapsed         | 722          |
# |    total_timesteps      | 976896       |
# | train/                  |              |
# |    approx_kl            | 0.0058465423 |
# |    clip_fraction        | 0.0662       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.48        |
# |    explained_variance   | 0.96         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5            |
# |    n_updates            | 4760         |
# |    policy_gradient_loss | 0.000108     |
# |    value_loss           | 12.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 283          |
# |    ep_rew_mean          | 239          |
# | time/                   |              |
# |    fps                  | 1353         |
# |    iterations           | 478          |
# |    time_elapsed         | 723          |
# |    total_timesteps      | 978944       |
# | train/                  |              |
# |    approx_kl            | 0.0047900593 |
# |    clip_fraction        | 0.0774       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.507       |
# |    explained_variance   | 0.975        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.3         |
# |    n_updates            | 4770         |
# |    policy_gradient_loss | 0.000384     |
# |    value_loss           | 12.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 284         |
# |    ep_rew_mean          | 244         |
# | time/                   |             |
# |    fps                  | 1354        |
# |    iterations           | 479         |
# |    time_elapsed         | 724         |
# |    total_timesteps      | 980992      |
# | train/                  |             |
# |    approx_kl            | 0.006007646 |
# |    clip_fraction        | 0.0846      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.353      |
# |    explained_variance   | 0.813       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11          |
# |    n_updates            | 4780        |
# |    policy_gradient_loss | -0.00333    |
# |    value_loss           | 39.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 283          |
# |    ep_rew_mean          | 245          |
# | time/                   |              |
# |    fps                  | 1354         |
# |    iterations           | 480          |
# |    time_elapsed         | 725          |
# |    total_timesteps      | 983040       |
# | train/                  |              |
# |    approx_kl            | 0.0039946306 |
# |    clip_fraction        | 0.0502       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.38        |
# |    explained_variance   | 0.875        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.17         |
# |    n_updates            | 4790         |
# |    policy_gradient_loss | -0.00141     |
# |    value_loss           | 23.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 283          |
# |    ep_rew_mean          | 245          |
# | time/                   |              |
# |    fps                  | 1354         |
# |    iterations           | 481          |
# |    time_elapsed         | 727          |
# |    total_timesteps      | 985088       |
# | train/                  |              |
# |    approx_kl            | 0.0038304604 |
# |    clip_fraction        | 0.068        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.46        |
# |    explained_variance   | 0.928        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.86         |
# |    n_updates            | 4800         |
# |    policy_gradient_loss | 0.000394     |
# |    value_loss           | 19           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 298         |
# |    ep_rew_mean          | 244         |
# | time/                   |             |
# |    fps                  | 1354        |
# |    iterations           | 482         |
# |    time_elapsed         | 729         |
# |    total_timesteps      | 987136      |
# | train/                  |             |
# |    approx_kl            | 0.008820691 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.462      |
# |    explained_variance   | 0.96        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.2         |
# |    n_updates            | 4810        |
# |    policy_gradient_loss | -0.00176    |
# |    value_loss           | 8.66        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 307         |
# |    ep_rew_mean          | 242         |
# | time/                   |             |
# |    fps                  | 1354        |
# |    iterations           | 483         |
# |    time_elapsed         | 730         |
# |    total_timesteps      | 989184      |
# | train/                  |             |
# |    approx_kl            | 0.017754512 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.555      |
# |    explained_variance   | 0.87        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.89        |
# |    n_updates            | 4820        |
# |    policy_gradient_loss | -0.000855   |
# |    value_loss           | 53.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 311         |
# |    ep_rew_mean          | 240         |
# | time/                   |             |
# |    fps                  | 1354        |
# |    iterations           | 484         |
# |    time_elapsed         | 731         |
# |    total_timesteps      | 991232      |
# | train/                  |             |
# |    approx_kl            | 0.009440285 |
# |    clip_fraction        | 0.0606      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.557      |
# |    explained_variance   | 0.969       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.59        |
# |    n_updates            | 4830        |
# |    policy_gradient_loss | -0.0017     |
# |    value_loss           | 13.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 308          |
# |    ep_rew_mean          | 242          |
# | time/                   |              |
# |    fps                  | 1355         |
# |    iterations           | 485          |
# |    time_elapsed         | 732          |
# |    total_timesteps      | 993280       |
# | train/                  |              |
# |    approx_kl            | 0.0075944993 |
# |    clip_fraction        | 0.0571       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.427       |
# |    explained_variance   | 0.729        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 167          |
# |    n_updates            | 4840         |
# |    policy_gradient_loss | -0.00353     |
# |    value_loss           | 161          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 307          |
# |    ep_rew_mean          | 241          |
# | time/                   |              |
# |    fps                  | 1355         |
# |    iterations           | 486          |
# |    time_elapsed         | 734          |
# |    total_timesteps      | 995328       |
# | train/                  |              |
# |    approx_kl            | 0.0077637136 |
# |    clip_fraction        | 0.0547       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.381       |
# |    explained_variance   | 0.803        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.4         |
# |    n_updates            | 4850         |
# |    policy_gradient_loss | -0.00328     |
# |    value_loss           | 32.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 243         |
# | time/                   |             |
# |    fps                  | 1355        |
# |    iterations           | 487         |
# |    time_elapsed         | 735         |
# |    total_timesteps      | 997376      |
# | train/                  |             |
# |    approx_kl            | 0.004233962 |
# |    clip_fraction        | 0.0577      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.407      |
# |    explained_variance   | 0.442       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 48.5        |
# |    n_updates            | 4860        |
# |    policy_gradient_loss | -0.00336    |
# |    value_loss           | 176         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 315          |
# |    ep_rew_mean          | 239          |
# | time/                   |              |
# |    fps                  | 1356         |
# |    iterations           | 488          |
# |    time_elapsed         | 737          |
# |    total_timesteps      | 999424       |
# | train/                  |              |
# |    approx_kl            | 0.0044282023 |
# |    clip_fraction        | 0.0465       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.474       |
# |    explained_variance   | 0.95         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.19         |
# |    n_updates            | 4870         |
# |    policy_gradient_loss | -0.000353    |
# |    value_loss           | 20.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 314          |
# |    ep_rew_mean          | 240          |
# | time/                   |              |
# |    fps                  | 1356         |
# |    iterations           | 489          |
# |    time_elapsed         | 738          |
# |    total_timesteps      | 1001472      |
# | train/                  |              |
# |    approx_kl            | 0.0052123684 |
# |    clip_fraction        | 0.0938       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.519       |
# |    explained_variance   | 0.853        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.5         |
# |    n_updates            | 4880         |
# |    policy_gradient_loss | -0.00338     |
# |    value_loss           | 67.5         |
# ------------------------------------------
# wandb: Network error (ReadTimeout), entering retry loop.

# %%
run.finish()
# Out:
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.284 MB of 0.284 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>global_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>rollout/ep_len_mean</td><td>▁▂▃▅▇███▇▅▄▄▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃</td></tr><tr><td>rollout/ep_rew_mean</td><td>▁▁▂▂▃▄▅▅▅▆▇▇███████████████████▇██▇██▇██</td></tr><tr><td>time/fps</td><td>█▆▃▂▂▁▁▁▁▁▁▁▂▂▂▂▂▂▂▂▂▂▂▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃</td></tr><tr><td>train/approx_kl</td><td>▅▄▃▇▆█▆▁▅▅▂▃▃▃▃▅▃▆▂▃▅▂▂▃▂▂▂▅▃▄▄▄▂▁▃▂▃▄▃▂</td></tr><tr><td>train/clip_fraction</td><td>▄▄▃█▅▃▆▁▄▅▂▃▃▂▃▆▃▆▁▃▃▃▃▃▂▂▂▅▃▄▃▃▂▁▃▂▃▄▄▄</td></tr><tr><td>train/clip_range</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/entropy_loss</td><td>▁▂▃▃▄▄▅▅▅▅▅▆▆▆▆▆▆▇▆▇▇▇▇▇▇▇▇▇▇▇█▇█████▇▇▇</td></tr><tr><td>train/explained_variance</td><td>▁▄▆▄▇▅█▅▇▆▇▇▆▇▇███▇▇▇▇█▃▅▆▇▇▇█▇▆▆▆▅▇█▇█▇</td></tr><tr><td>train/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/loss</td><td>█▆▆▃▁▂▁▁▄▂▆▁▇▁▁▅▁▁▃▁▂█▁▁▂▁▆▁▂▂▁▃▃▆▂▂▁▂▁▂</td></tr><tr><td>train/policy_gradient_loss</td><td>▃▁▄▂▅▅▃▆▆▅▆▅▃▆▇▄▅▆▆▆▅▅▆▅▆▇▆▅█▄▇▆▆▇▆▅█▆█▅</td></tr><tr><td>train/value_loss</td><td>█▄▃▂▁▂▁▃▂▂▂▁▃▁▁▂▁▁▃▁▁▂▁▃▂▂▃▁▁▁▁▂▄▃▁▁▁▂▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>global_step</td><td>1001472</td></tr><tr><td>rollout/ep_len_mean</td><td>314.26001</td></tr><tr><td>rollout/ep_rew_mean</td><td>239.78058</td></tr><tr><td>time/fps</td><td>1356.0</td></tr><tr><td>train/approx_kl</td><td>0.00521</td></tr><tr><td>train/clip_fraction</td><td>0.09385</td></tr><tr><td>train/clip_range</td><td>0.2</td></tr><tr><td>train/entropy_loss</td><td>-0.51855</td></tr><tr><td>train/explained_variance</td><td>0.85302</td></tr><tr><td>train/learning_rate</td><td>0.0003</td></tr><tr><td>train/loss</td><td>12.52925</td></tr><tr><td>train/policy_gradient_loss</td><td>-0.00338</td></tr><tr><td>train/value_loss</td><td>67.48019</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">upbeat-waterfall-11</strong>: <a href="https://wandb.ai/deutschmann/hf-deep-rl-class/runs/2cn87197" target="_blank">https://wandb.ai/deutschmann/hf-deep-rl-class/runs/2cn87197</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220506_084747-2cn87197/logs</code>

# %%
# Define the name of the environment
env_id = env_name

# Create the evaluation env
eval_env = DummyVecEnv([lambda: gym.make(env_id)])

# Define the model architecture we used
model_architecture = "PPO"

## Define a repo_id
## repo_id is the id of the model repository from the Hugging Face Hub (repo_id = {organization}/{repo_name} for instance ThomasSimonini/ppo-LunarLander-v2
repo_id = "deutschmann/ppo-LunarLander-v2"

## Define the commit message
commit_message = "Longer training"

model_name = "PPO-MLP"

# method save, evaluate, generate a model card and record a replay video of your agent before pushing the repo to the hub
package_to_hub(model=model, # Our trained model
               model_name=model_name, # The name of our trained model 
               model_architecture=model_architecture, # The model architecture we used: in our case PPO
               env_id=env_id, # Name of the environment
               eval_env=eval_env, # Evaluation Environment
               repo_id=repo_id, # id of the model repository from the Hugging Face Hub (repo_id = {organization}/{repo_name} for instance ThomasSimonini/ppo-LunarLander-v2
               commit_message=commit_message)
# Out:
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to 1min.
# This is a work in progress: If you encounter a bug, please open an issue and use
# push_to_hub instead.
# /Users/patrick/.pyenv/versions/3.9.11/envs/hf-deep-rl-class/lib/python3.9/site-packages/huggingface_hub/hf_api.py:79: FutureWarning: `name` and `organization` input arguments are deprecated and will be removed in v0.7. Pass `repo_id` instead.
#   warnings.warn(
# /Users/patrick/Projects/deep-rl-class/unit1/hub/ppo-LunarLander-v2 is already a clone of https://huggingface.co/deutschmann/ppo-LunarLander-v2. Make sure you pull the latest changes with `repo.git_pull()`.
# /Users/patrick/.pyenv/versions/3.9.11/envs/hf-deep-rl-class/lib/python3.9/site-packages/stable_baselines3/common/evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Saving video to /Users/patrick/Projects/deep-rl-class/unit1/-step-0-to-step-1000.mp4
# ffmpeg version 5.0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with Apple clang version 13.1.6 (clang-1316.0.21.2)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/5.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-neon
#   libavutil      57. 17.100 / 57. 17.100
#   libavcodec     59. 18.100 / 59. 18.100
#   libavformat    59. 16.100 / 59. 16.100
#   libavdevice    59.  4.100 / 59.  4.100
#   libavfilter     8. 24.100 /  8. 24.100
#   libswscale      6.  4.100 /  6.  4.100
#   libswresample   4.  3.100 /  4.  3.100
#   libpostproc    56.  3.100 / 56.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from './test.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf59.16.100
#   Duration: 00:00:20.02, start: 0.000000, bitrate: 157 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1200x800, 152 kb/s, 50 fps, 50 tbr, 12800 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x149705580] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x149705580] profile High, level 3.2, 4:2:0, 8-bit
# [libx264 @ 0x149705580] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=15 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'replay.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf59.16.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 1200x800, q=2-31, 50 fps, 12800 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc59.18.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame= 1001 fps=984 q=-1.0 Lsize=     377kB time=00:00:19.96 bitrate= 154.9kbits/s speed=19.6x
# video:365kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 3.385346%
# [libx264 @ 0x149705580] frame I:5     Avg QP:11.33  size:  3696
# [libx264 @ 0x149705580] frame P:271   Avg QP:22.56  size:   459
# [libx264 @ 0x149705580] frame B:725   Avg QP:25.18  size:   318
# [libx264 @ 0x149705580] consecutive B-frames:  0.9%  5.0%  7.8% 86.3%
# [libx264 @ 0x149705580] mb I  I16..4: 69.2% 28.0%  2.8%
# [libx264 @ 0x149705580] mb P  I16..4:  0.2%  0.4%  0.2%  P16..4:  1.0%  0.3%  0.1%  0.0%  0.0%    skip:98.0%
# [libx264 @ 0x149705580] mb B  I16..4:  0.0%  0.0%  0.1%  B16..8:  1.7%  0.2%  0.0%  direct: 0.0%  skip:97.9%  L0:56.2% L1:43.2% BI: 0.6%
# [libx264 @ 0x149705580] 8x8 transform intra:31.4% inter:12.0%
# [libx264 @ 0x149705580] coded y,uvDC,uvAC intra: 9.5% 18.1% 16.4% inter: 0.1% 0.1% 0.0%
# [libx264 @ 0x149705580] i16 v,h,dc,p: 91%  6%  3%  0%
# [libx264 @ 0x149705580] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 21% 22% 56%  0%  0%  0%  0%  0%  0%
# [libx264 @ 0x149705580] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 15% 14% 54%  2%  4%  2%  3%  2%  2%
# [libx264 @ 0x149705580] i8c dc,h,v,p: 91%  5%  4%  0%
# [libx264 @ 0x149705580] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x149705580] ref P L0: 69.6%  1.5% 19.5%  9.3%
# [libx264 @ 0x149705580] ref B L0: 67.6% 29.2%  3.2%
# [libx264 @ 0x149705580] ref B L1: 94.6%  5.4%
# [libx264 @ 0x149705580] kb/s:149.10
# ℹ Pushing repo ppo-LunarLander-v2 to the Hugging Face Hub
# Upload file replay.mp4:   8%|8         | 32.0k/377k [00:00<?, ?B/s]
# Upload file PPO-MLP/policy.optimizer.pth:  39%|###8      | 32.0k/82.7k [00:00<?, ?B/s]
# Upload file PPO-MLP.zip:  23%|##2       | 32.0k/140k [00:00<?, ?B/s]
# Upload file PPO-MLP/policy.pth:  76%|#######6  | 32.0k/42.1k [00:00<?, ?B/s]
# remote: Enforcing permissions...
# remote: Allowed refs: all
# To https://huggingface.co/deutschmann/ppo-LunarLander-v2
#    007b0e4..5ef6c5c  main -> main
# ℹ Your model is pushed to the hub. You can view your model here:
# https://huggingface.co/deutschmann/ppo-LunarLander-v2
# 'https://huggingface.co/deutschmann/ppo-LunarLander-v2'
